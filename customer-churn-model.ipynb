# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score

# %%
"""import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
df=pd.read_csv("C:/Users/HP/Downloads/telecom_churn_large.csv")
df.head()
df.shape
df.isnull().sum()
df.info()
df["Churn"].value_counts()
df.drop(columns=["customerID","gender","Partner","Dependents"],axis=1,inplace=True)
num=[]
for i in df.columns:
    if df[i].dtypes=="int64" or df[i].dtypes=="float64":
        num.append(i)

cat=[]
for i in df.columns:
    if df[i].dtypes=="object":
        cat.append(i)

num
cat
for i in cat:
    print(df[i].value_counts())
    print("\n")


df["MultipleLines"]=df["MultipleLines"].replace("No phone service","No")
df["OnlineSecurity"]=df["OnlineSecurity"].replace("No internet service", "No")
df["OnlineBackup"]=df["OnlineBackup"].replace("No internet service", "No")
df["DeviceProtection"]=df["DeviceProtection"].replace("No internet service", "No")
df["TechSupport"]=df["TechSupport"].replace("No internet service", "No")
df["StreamingTV"]=df["StreamingTV"].replace("No internet service", "No")
df["StreamingMovies"]=df["StreamingMovies"].replace("No internet service", "No")

for i in cat:
    print(df[i].value_counts())
    print("\n")


one=["PaymentMethod","Contract","InternetService"]
la=['PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']
df["Churn"]=df["Churn"].map({"Yes" :1, "No" :0})
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
preprocessor=ColumnTransformer(transformers=[("scale_num", StandardScaler(),num),
                                ("encode_bin",OrdinalEncoder(),la),
                                ("encode_multi",OneHotEncoder(handle_unknown="ignore"), one)])
pipe=Pipeline(steps=[("preprocess",preprocessor),("model",LogisticRegression(max_iter=1000,class_weight="balanced",random_state=42))])
pipe.fit(x_train,y_train)"""

# %%
df=pd.read_csv("C:/Users/HP/Downloads/telecom_churn_large.csv")

# %%
df.head()

# %%
df.shape

# %%
df.isnull().sum()

# %%
df.info()

# %%
df["Churn"].value_counts()

# %%
df.drop(columns=["customerID","gender","Partner","Dependents"],axis=1,inplace=True)

# %%
df.head(3)

# %%
df["PhoneService"].value_counts()

# %%
df["PaymentMethod"].value_counts()

# %%
df["OnlineBackup"].value_counts()

# %%
num=[]
for i in df.columns:
    if df[i].dtypes=="int64" or df[i].dtypes=="float64":
        num.append(i)

# %%
cat=[]
for i in df.columns:
    if df[i].dtypes=="object":
        cat.append(i)

# %%
num
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
cat
# Out:
# ['PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
for i in cat:
    print(df[i].value_counts())
    print("\n")
# Out:
# PhoneService
# No     5100
# Yes    4900
# Name: count, dtype: int64
#
#
# MultipleLines
# No                  3348
# No phone service    3343
# Yes                 3309
# Name: count, dtype: int64
#
#
# InternetService
# DSL            3372
# Fiber optic    3346
# No             3282
# Name: count, dtype: int64
#
#
# OnlineSecurity
# Yes                    3365
# No                     3347
# No internet service    3288
# Name: count, dtype: int64
#
#
# OnlineBackup
# No                     3389
# No internet service    3316
# Yes                    3295
# Name: count, dtype: int64
#
#
# DeviceProtection
# Yes                    3379
# No                     3350
# No internet service    3271
# Name: count, dtype: int64
#
#
# TechSupport
# Yes                    3384
# No internet service    3348
# No                     3268
# Name: count, dtype: int64
#
#
# StreamingTV
# Yes                    3374
# No                     3344
# No internet service    3282
# ...

# %%
df["MultipleLines"]=df["MultipleLines"].replace("No phone service","No")
df["OnlineSecurity"]=df["OnlineSecurity"].replace("No internet service", "No")
df["OnlineBackup"]=df["OnlineBackup"].replace("No internet service", "No")
df["DeviceProtection"]=df["DeviceProtection"].replace("No internet service", "No")
df["TechSupport"]=df["TechSupport"].replace("No internet service", "No")
df["StreamingTV"]=df["StreamingTV"].replace("No internet service", "No")
df["StreamingMovies"]=df["StreamingMovies"].replace("No internet service", "No")

for i in cat:
    print(df[i].value_counts())
    print("\n")
# Out:
# PhoneService
# No     5100
# Yes    4900
# Name: count, dtype: int64
#
#
# MultipleLines
# No     6691
# Yes    3309
# Name: count, dtype: int64
#
#
# InternetService
# DSL            3372
# Fiber optic    3346
# No             3282
# Name: count, dtype: int64
#
#
# OnlineSecurity
# No     6635
# Yes    3365
# Name: count, dtype: int64
#
#
# OnlineBackup
# No     6705
# Yes    3295
# Name: count, dtype: int64
#
#
# DeviceProtection
# No     6621
# Yes    3379
# Name: count, dtype: int64
#
#
# TechSupport
# No     6616
# Yes    3384
# Name: count, dtype: int64
#
#
# StreamingTV
# No     6626
# Yes    3374
# Name: count, dtype: int64
#
#
# StreamingMovies
# No     6695
# Yes    3305
# Name: count, dtype: int64
#
#
# Contract
# One year          3347
# Two year          3328
# Month-to-month    3325
# Name: count, dtype: int64
#
#
# PaperlessBilling
# Yes    5136
# No     4864
# Name: count, dtype: int64
#
#
# PaymentMethod
# Mailed check        2544
# Bank transfer       2530
# ...

# %%
for i in cat:
    print(df[i].value_counts())
    print("\n")
# Out:
# PhoneService
# No     5100
# Yes    4900
# Name: count, dtype: int64
#
#
# MultipleLines
# No     6691
# Yes    3309
# Name: count, dtype: int64
#
#
# InternetService
# DSL            3372
# Fiber optic    3346
# No             3282
# Name: count, dtype: int64
#
#
# OnlineSecurity
# No     6635
# Yes    3365
# Name: count, dtype: int64
#
#
# OnlineBackup
# No     6705
# Yes    3295
# Name: count, dtype: int64
#
#
# DeviceProtection
# No     6621
# Yes    3379
# Name: count, dtype: int64
#
#
# TechSupport
# No     6616
# Yes    3384
# Name: count, dtype: int64
#
#
# StreamingTV
# No     6626
# Yes    3374
# Name: count, dtype: int64
#
#
# StreamingMovies
# No     6695
# Yes    3305
# Name: count, dtype: int64
#
#
# Contract
# One year          3347
# Two year          3328
# Month-to-month    3325
# Name: count, dtype: int64
#
#
# PaperlessBilling
# Yes    5136
# No     4864
# Name: count, dtype: int64
#
#
# PaymentMethod
# Mailed check        2544
# Bank transfer       2530
# ...

# %%
one=["PaymentMethod","Contract","InternetService"]

# %%
la=['PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']

# %%
df["Churn"]=df["Churn"].map({"Yes" :1, "No" :0})

# %%
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Churn, Length: 10000, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
preprocessor=ColumnTransformer(transformers=[("scale_num", StandardScaler(),num),
                                ("encode_bin",OrdinalEncoder(),la),
                                ("encode_multi",OneHotEncoder(handle_unknown="ignore"), one)])

# %%
pipe=Pipeline(steps=[("preprocess",preprocessor),("model",LogisticRegression(max_iter=1000,class_weight="balanced",random_state=42))])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('scale_num', StandardScaler(),
#                                                   ['SeniorCitizen', 'tenure',
#                                                    'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('encode_bin',
#                                                   OrdinalEncoder(),
#                                                   ['PhoneService',
#                                                    'MultipleLines',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
# ...

# %%
y_pred=pipe.predict(x_test)

# %%
y_proba=pipe.predict_proba(x_test)[:,1]

# %%
print("accuracy_score",accuracy_score(y_test,y_pred))
print("\nclassification_report:\n",classification_report(y_test,y_pred))
print("\n confusion matrix\n", confusion_matrix(y_test,y_pred))
print("\n roc-auc: \n",roc_auc_score(y_test,y_proba))
# Out:
# accuracy_score 0.5295
#
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.53      0.62      1481
#            1       0.28      0.53      0.37       519
#
#     accuracy                           0.53      2000
#    macro avg       0.52      0.53      0.50      2000
# weighted avg       0.64      0.53      0.56      2000
#
#
#  confusion matrix
#  [[783 698]
#  [243 276]]
#
#  roc-auc:
#  0.5201245318023155

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipe=Pipeline(steps=[("preprocessor",preprocessor),("model", RandomForestClassifier(n_estimators=1000,max_depth=20,min_samples_split=20,min_samples_leaf=10,class_weight="balanced"))])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('scale_num', StandardScaler(),
#                                                   ['SeniorCitizen', 'tenure',
#                                                    'MonthlyCharges',
#                                                    'TotalCharges']),
#                                                  ('encode_bin',
#                                                   OrdinalEncoder(),
#                                                   ['PhoneService',
#                                                    'MultipleLines',
#                                                    'OnlineSecurity',
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
# ...

# %%
y_pred=pipe.predict(x_test)

# %%
y_proba=pipe.predict_proba(x_test)[:,1]

# %%
print("accuracy_score",accuracy_score(y_test,y_pred))
print("\nclassification_report:\n",classification_report(y_test,y_pred))
print("\n confusion matrix\n", confusion_matrix(y_test,y_pred))
print("\n roc-auc: \n",roc_auc_score(y_test,y_proba))
# Out:
# accuracy_score 0.696
#
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81      1481
#            1       0.29      0.12      0.16       519
#
#     accuracy                           0.70      2000
#    macro avg       0.52      0.51      0.49      2000
# weighted avg       0.63      0.70      0.65      2000
#
#
#  confusion matrix
#  [[1332  149]
#  [ 459   60]]
#
#  roc-auc:
#  0.5018675867344748

# %%
# !pip install imbalanced-learn
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer,roc_auc_score

# %%
"""from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from imblearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer,roc_auc_score
imb_pipe=ImbPipeline([("preprocessor",preprocessor),"smote",SMOTE(k_neighbors=10,random_state=42),
                      "model",RandomForestClassifier(class_weight="balanced_subsample,random_state=42")])
param_dist={"model_n_estimators":[200,400,600,800,1000],
"model_max_depth":[5,10,15,20,25],
"model_min_samples_split":[5,10,15,20],
"model_min_samples_leaf":[5,10,15,20]}

rnd_search=ImbRandomizedSearchCV(estimator=imb_pipe,param_distributions=param_dist,n_iter=20,scoring="roc_auc",cv=4,verbose=2,random_state=42,n_jobs=-1)
rnd.search.fit(x_train,y_train)
best_pipe=rnd_search.best_estimator_
print("best params:" rnd_search.best_params_)
print("best cv roc_auc:"rnd_search.best_score_)
y_pred=best_pipe.predict(x_test)
y_proba=best_pipe.predict_proba(x_test)[:,1]
print("accuracy_score",accuracy_score(y_test,y_pred))
print("\nclassification_report:\n",classification_report(y_test,y_pred))
print("\n confusion matrix\n", confusion_matrix(y_test,y_pred))
print("\n roc-auc: \n",roc_auc_score(y_test,y_proba))"""
# Out:
# 'from imblearn.pipeline import Pipeline as ImbPipeline\nfrom imblearn.over_sampling import SMOTE\nfrom imblearn.model_selection import RandomizedSearchCV\nfrom sklearn.ensemble import RandomForestClassifier\nfrom sklearn.metrics import make_scorer,roc_auc_score\nimb_pipe=ImbPipeline([("preprocessor",preprocessor),"smote",SMOTE(k_neighbors=10,random_state=42),\n                      "model",RandomForestClassifier(class_weight="balanced_subsample,random_state=42")])\nparam_dist={"model_n_estimators":[200,400,600,800,1000],\n"model_max_depth":[5,10,15,20,25],\n"model_min_samples_split":[5,10,15,20],\n"model_min_samples_leaf":[5,10,15,20]}\n\nrnd_search=ImbRandomizedSearchCV(estimator=imb_pipe,param_distributions=param_dist,n_iter=20,scoring="roc_auc",cv=4,verbose=2,random_state=42,n_jobs=-1)\nrnd.search.fit(x_train,y_train)\nbest_pipe=rnd_search.best_estimator_\nprint("best params:" rnd_search.best_params_)\nprint("best cv roc_auc:"rnd_search.best_score_)\ny_pred=best_pipe.predict(x_tes
# ...

# %%
imb_pipe=ImbPipeline([("preprocessor",preprocessor),("smote",SMOTE(k_neighbors=10,random_state=42)),
                      ("model",RandomForestClassifier(class_weight="balanced_subsample",random_state=42,n_jobs=-1))])

# %%
param_dist={"model__n_estimators":[200,400,600,800,1000],
"model__max_depth":[5,10,15,20,25],
"model__min_samples_split":[5,10,15,20],
"model__min_samples_leaf":[5,10,15,20]}

# %%
rnd_search=RandomizedSearchCV(estimator=imb_pipe,param_distributions=param_dist,n_iter=20,scoring= 'roc_auc' ,cv=4,verbose=2,random_state=42,n_jobs=-1) 

# Corrected line:
rnd_search.fit(x_train,y_train) 

best_pipe=rnd_search.best_estimator_
print('best params:', rnd_search.best_params_)
print('best cv roc_auc:', rnd_search.best_score_)
# Out:
# Fitting 4 folds for each of 20 candidates, totalling 80 fits

# %%
y_pred=best_pipe.predict(x_test)

# %%
y_proba=best_pipe.predict_proba(x_test)[:,1]

# %%
print("accuracy_score",accuracy_score(y_test,y_pred))
print("\nclassification_report:\n",classification_report(y_test,y_pred))
print("\n confusion matrix\n", confusion_matrix(y_test,y_pred))
print("\n roc-auc: \n",roc_auc_score(y_test,y_proba))

# %%
"""from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
gbpipe=ImbPipeline(steps=([("preprocessor",preprocessor),("smote",SMOTE(k_neighbors=10,random_state=42,n_jobs=-1)),
                        ("model",GradientBoostingClassifier(learning_rate=0.05,n_estimators=1000,max_depth=3))]))
param_dist={"model__n_estimators":[200,400,600,800,1000],
"model__max_depth":[5,10,15,20,25],
"model__min_samples_split":[5,10,15,20],
"model__min_samples_leaf":[5,10,15,20]}
gbsearch=GridSearchCV(estimator=gbpipe,param_grid=param_dist,cv=5,n_jobs=-1,scoring="recall")
gbsearch.fit(x_train,y_train)"""

# %%
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

# %%
gbpipe=Pipeline(steps=([("preprocessor",preprocessor),("smote",SMOTE(k_neighbors=10,random_state=42,n_jobs=1)),
                        ("model",GradientBoostingClassifier(learning_rate=0.05,n_estimators=1000,max_depth=3))]))

# %%
param_dist={"model__n_estimators":[200,400,600,800,1000],
"model__max_depth":[5,10,15,20,25],
"model__min_samples_split":[5,10,15,20],
"model__min_samples_leaf":[5,10,15,20]}

# %%
gbsearch=GridSearchCV(estimator=gbpipe,param_grid=param_dist,cv=5,n_jobs=1,scoring="recall")

# %%
gbsearch.fit(x_train,y_train)
